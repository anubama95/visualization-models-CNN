# %%
import os, shutil

original_dataset_dir = '/home/asus/Desktop/Dataset/'

classes_list = os.listdir(original_dataset_dir)

base_dir = './home/asus/Desktop/Dataset_splits'
os.mkdir(base_dir)

train_dir = os.path.join(base_dir, 'train')
os.mkdir(train_dir)
validation_dir = os.path.join(base_dir, 'validation')
os.mkdir(validation_dir)
test_dir = os.path.join(base_dir, 'test')
os.mkdir(test_dir)


for cls in classes_list:
    os.mkdir(os.path.join(train_dir, cls))
    
    os.mkdir(os.path.join(validation_dir, cls))
     
    os.mkdir(os.path.join(test_dir, cls))

# %%
import math

for cls in classes_list:
    path = os.path.join(original_dataset_dir, cls)
    fnames = os.listdir(path)
    train_size = math.floor(len(fnames) * 0.8)
    validation_size = math.floor(len(fnames) * 0.15)
    test_size = math.floor(len(fnames) * 0.05)
    
    train_fnames = fnames[:train_size]
    print("Train size(",cls,"): ", len(train_fnames))
    for fname in train_fnames:
        src = os.path.join(path, fname)
        dst = os.path.join(os.path.join(train_dir, cls), fname)
        shutil.copyfile(src, dst)
        
    validation_fnames = fnames[train_size:(validation_size + train_size)]
    print("Validation size(",cls,"): ", len(validation_fnames))
    for fname in validation_fnames:
        src = os.path.join(path, fname)
        dst = os.path.join(os.path.join(validation_dir, cls), fname)
        shutil.copyfile(src, dst)
        
    
    test_fnames = fnames[(train_size+validation_size):(validation_size + train_size +test_size)]
    print("Test size(",cls,"): ", len(test_fnames))
    for fname in test_fnames:
        src = os.path.join(path, fname)
        dst = os.path.join(os.path.join(test_dir, cls), fname)
        shutil.copyfile(src, dst)
# Out:
# Train size( GD_Healthy ):  500
# Validation size( GD_Healthy ):  93
# Test size( GD_Healthy ):  31
# Train size( GD_Leaf_Blight ):  353
# Validation size( GD_Leaf_Blight ):  66
# Test size( GD_Leaf_Blight ):  22
# Train size( Tomato_Septoria_leaf_spot ):  1416
# Validation size( Tomato_Septoria_leaf_spot ):  265
# Test size( Tomato_Septoria_leaf_spot ):  88
# Train size( Tomato_Spider_mites_Two_spotted_spider_mite ):  1340
# Validation size( Tomato_Spider_mites_Two_spotted_spider_mite ):  251
# Test size( Tomato_Spider_mites_Two_spotted_spider_mite ):  83
# Train size( pomo_Bacterial_Blight ):  20
# Validation size( pomo_Bacterial_Blight ):  3
# Test size( pomo_Bacterial_Blight ):  1
# Train size( pomo_Cercospora_LeafSpot ):  20
# Validation size( pomo_Cercospora_LeafSpot ):  3
# Test size( pomo_Cercospora_LeafSpot ):  1
# Train size( Potato___Late_blight ):  800
# Validation size( Potato___Late_blight ):  150
# Test size( Potato___Late_blight ):  50
# Train size( Corn_(maize)___Common_rust_ ):  953
# Validation size( Corn_(maize)___Common_rust_ ):  178
# Test size( Corn_(maize)___Common_rust_ ):  59
# Train size( Tomato_healthy ):  1272
# Validation size( Tomato_healthy ):  238
# Test size( Tomato_healthy ):  79
# Train size( GD_Webbloch ):  372
# Validation size( GD_Webbloch ):  69
# Test size( GD_Webbloch ):  23
# Train size( Tomato_Late_blight ):  1527
# Validation size( Tomato_Late_blight ):  286
# Test size( Tomato_Late_blight ):  95
# Train size( pomo_Alternaria_Alternata ):  20
# Validation size( pomo_Alternaria_Alternata ):  3
# Test size( pomo_Alternaria_Alternata ):  1
# Train size( Pepper__bell___Bacterial_spot ):  797
# Validation size( Pepper__bell___Bacterial_spot ):  149
# Test size( Pepper__bell___Bacterial_spot ):  49
# Train size( Paddy_Bacterial_leaf_blight ):  108
# Validation size( Paddy_Bacterial_leaf_blight ):  20
# Test size( Paddy_Bacterial_leaf_blight ):  6
# Train size( Potato___healthy ):  121
# Validation size( Potato___healthy ):  22
# Test size( Potato___healthy ):  7
# Train size( Tomato__Tomato_mosaic_virus ):  298
# Validation size( Tomato__Tomato_mosaic_virus ):  55
# Test size( Tomato__Tomato_mosaic_virus ):  18
# Train size( GD_Rust ):  208
# Validation size( GD_Rust ):  39
# Test size( GD_Rust ):  13
# Train size( Pepper__bell___healthy ):  1182
# Validation size( Pepper__bell___healthy ):  221
# Test size( Pepper__bell___healthy ):  73
# Train size( GD_Deficiency ):  710
# Validation size( GD_Deficiency ):  133
# Test size( GD_Deficiency ):  44
# Train size( GD_Toxicity ):  124
# Validation size( GD_Toxicity ):  23
# Test size( GD_Toxicity ):  7
# Train size( pomo_Healthy_Leaves ):  20
# Validation size( pomo_Healthy_Leaves ):  3
# Test size( pomo_Healthy_Leaves ):  1
# Train size( Potato___Early_blight ):  800
# Validation size( Potato___Early_blight ):  150
# Test size( Potato___Early_blight ):  50
# Train size( Tomato__Target_Spot ):  1123
# Validation size( Tomato__Target_Spot ):  210
# Test size( Tomato__Target_Spot ):  70
# Train size( Tomato__Tomato_YellowLeaf__Curl_Virus ):  2567
# Validation size( Tomato__Tomato_YellowLeaf__Curl_Virus ):  481
# Test size( Tomato__Tomato_YellowLeaf__Curl_Virus ):  160
# Train size( Tomato_Early_blight ):  800
# Validation size( Tomato_Early_blight ):  150
# Test size( Tomato_Early_blight ):  50
# Train size( GD_Alternia ):  619
# Validation size( GD_Alternia ):  116
# Test size( GD_Alternia ):  38
# Train size( Tomato_Bacterial_spot ):  1701
# Validation size( Tomato_Bacterial_spot ):  319
# Test size( Tomato_Bacterial_spot ):  106
# Train size( Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot ):  410
# Validation size( Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot ):  76
# Test size( Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot ):  25
# Train size( Tomato_Leaf_Mold ):  761
# Validation size( Tomato_Leaf_Mold ):  142
# Test size( Tomato_Leaf_Mold ):  47
# Train size( Corn_(maize)___healthy ):  929
# Validation size( Corn_(maize)___healthy ):  174
# Test size( Corn_(maize)___healthy ):  58
# Train size( Paddy_Brown_spot ):  108
# Validation size( Paddy_Brown_spot ):  20
# Test size( Paddy_Brown_spot ):  6
# Train size( GD_Spidermites ):  112
# Validation size( GD_Spidermites ):  21
# Test size( GD_Spidermites ):  7
# Train size( pomo_Anthracnose ):  20
# Validation size( pomo_Anthracnose ):  3
# Test size( pomo_Anthracnose ):  1
